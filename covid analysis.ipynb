# %% [markdown]
# # Importing Required Libraries and Dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('covid status.csv')
df
# Out:
#                                    State/UTs  Total Cases   Active  \
# 0                        Andaman and Nicobar         7525       14
# 1                             Andhra Pradesh      1952513    22358
# 2                          Arunachal Pradesh        45703     4465
# 3                                      Assam       557437    15726
# 4                                      Bihar       724390      530
# 5                                 Chandigarh        61922       32
# 6                               Chhattisgarh      1001037     2789
# 7   Dadra and Nagar Haveli and Daman and Diu        10637       48
# 8                                      Delhi      1435844      587
# 9                                        Goa       170416     1238
# 10                                   Gujarat       824683      342
# 11                                   Haryana       769717      740
# 12                          Himachal Pradesh       205017      931
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
df.head
# Out:
# <bound method NDFrame.head of                                    State/UTs  Total Cases   Active  \
# 0                        Andaman and Nicobar         7525       14
# 1                             Andhra Pradesh      1952513    22358
# 2                          Arunachal Pradesh        45703     4465
# 3                                      Assam       557437    15726
# 4                                      Bihar       724390      530
# 5                                 Chandigarh        61922       32
# 6                               Chhattisgarh      1001037     2789
# 7   Dadra and Nagar Haveli and Daman and Diu        10637       48
# 8                                      Delhi      1435844      587
# 9                                        Goa       170416     1238
# 10                                   Gujarat       824683      342
# 11                                   Haryana       769717      740
# 12                          Himachal Pradesh       205017      931
# ...

# %%
df.describe()
# Out:
#         Total Cases        Active    Discharged         Deaths  \
# count  3.600000e+01  3.600000e+01  3.600000e+01      36.000000
# mean   8.714417e+05  4.599578e+04  8.484205e+05   11681.972222
# std    1.255645e+06  2.303794e+05  1.213779e+06   22587.031797
# min    7.525000e+03  1.400000e+01  7.382000e+03       4.000000
# 25%    6.159075e+04  4.830000e+02  5.952950e+04     791.500000
# 50%    4.521775e+05  1.275000e+03  4.390575e+05    5119.000000
# 75%    9.745455e+05  9.781500e+03  9.543658e+05   13308.500000
# max    6.258079e+06  1.386262e+06  6.029817e+06  131429.000000
#
#        Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# count         36.000000            36.000000        36.000000
# mean           2.665833            96.074722         1.260000
# std            4.985038             4.877221         0.565241
# min            0.020000            74.610000         0.040000
# 25%            0.122500            96.327500         0.935000
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                                    State/UTs  Total Cases   Active  \
# 0                        Andaman and Nicobar         7525       14
# 1                             Andhra Pradesh      1952513    22358
# 2                          Arunachal Pradesh        45703     4465
# 3                                      Assam       557437    15726
# 4                                      Bihar       724390      530
# 5                                 Chandigarh        61922       32
# 6                               Chhattisgarh      1001037     2789
# 7   Dadra and Nagar Haveli and Daman and Diu        10637       48
# 8                                      Delhi      1435844      587
# 9                                        Goa       170416     1238
# 10                                   Gujarat       824683      342
# 11                                   Haryana       769717      740
# 12                          Himachal Pradesh       205017      931
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
df.shape
# Out:
# (36, 8)

# %%
df.isnull().values.any()
# Out:
# False

# %%
# Count of null values
df.isnull().sum()
# Out:
# State/UTs              0
# Total Cases            0
# Active                 0
# Discharged             0
# Deaths                 0
# Active Ratio (%)       0
# Discharge Ratio (%)    0
# Death Ratio (%)        0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# Lets look at the distribution of all the numeric variables
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
df.corr()
# Out:
#                      Total Cases    Active  Discharged    Deaths  \
# Total Cases             1.000000  0.386029    0.999919  0.915217
# Active                  0.386029  1.000000    0.378549  0.099266
# Discharged              0.999919  0.378549    1.000000  0.914909
# Deaths                  0.915217  0.099266    0.914909  1.000000
# Active Ratio (%)       -0.195362  0.056235   -0.200224 -0.169711
# Discharge Ratio (%)     0.187941 -0.031479    0.192844  0.139060
# Death Ratio (%)         0.101944 -0.224457    0.102526  0.297156
#
#                      Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# Total Cases                 -0.195362             0.187941         0.101944
# Active                       0.056235            -0.031479        -0.224457
# Discharged                  -0.200224             0.192844         0.102526
# Deaths                      -0.169711             0.139060         0.297156
# ...

# %%
# Correlation matrix graph of the data set
f, ax = plt.subplots(figsize= [20,15])
sns.heatmap(df.corr(), annot=True, fmt=".2f", ax=ax, cmap = "vlag" )
ax.set_title("Correlation Matrix", fontsize=20) 
plt.show()

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
df['Active Ratio (%)'].plot(figsize=(16, 6))
df.rolling(100).mean()['Active Ratio (%)'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing and Model Evaluation

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
sns.countplot(df['Active Ratio (%)'],palette="magma")
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Active Ratio (%)', ylabel='count'>

# %%
sns.countplot(df['Death Ratio (%)'],palette="magma")
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Death Ratio (%)', ylabel='count'>

# %%
sns.countplot(df['Discharge Ratio (%)'],palette="magma")
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Discharge Ratio (%)', ylabel='count'>

# %%
sns.countplot(df['Total Cases'],palette="magma")
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Total Cases', ylabel='count'>

# %%
sns.countplot(df['Active'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Active', ylabel='count'>

# %%
sns.countplot(df['Discharged'],palette="magma")
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Discharged', ylabel='count'>

# %%
sns.countplot(df['Deaths'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Deaths', ylabel='count'>

# %%
import matplotlib.pyplot as plt
fig_dims = (20, 12)
fig, ax = plt.subplots(figsize=fig_dims)

#ax = axis
sns.countplot(x='Deaths', hue='Discharged', data = df, palette="colorblind", ax = ax,  edgecolor=sns.color_palette("dark", n_colors = 1));

# %%
# Top 5 active cases in the country
top_5 = df.sort_values(by=['Active'], ascending=False).head()

### Generate a Barplot
plt.figure(figsize=(15,5))
Active = sns.barplot(top_5['Active'], top_5['State/UTs'], color = 'red', label='Confirmed')
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Top 5 total cases in the country
top_5 = df.sort_values(by=['Total Cases'], ascending=False).head()

plt.figure(figsize=(15,5))
Total = sns.barplot(top_5['Total Cases'], top_5['State/UTs'], color = 'yellow', label='Total Cases')
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Plotting State/UTs vs Total Cases
plt.figure(figsize=(20,8))
Plot = sns.barplot(x="State/UTs", y="Total Cases", data=df)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mtd
import seaborn as sns
from matplotlib.ticker import ScalarFormatter
colors=['#0C68C7','#3A6794','#00FAF3','#FA643C','#C71D12']
sns.set(palette=colors, style='white')

sns.palplot(colors)

# %%
top_10=df.groupby(by='State/UTs').max()[['Active']].sort_values(by=['Active'],ascending=False).reset_index()
with plt.xkcd():
    fig=plt.figure(figsize=(15,8))
    plt.title("Top 10 highly impacted sates as on 8th May", size=20)
    ax=sns.barplot(data=top_10.iloc[:10],y='Active',x='State/UTs', linewidth=2, edgecolor='black')
    ax.set_xticklabels(labels=ax.get_xticklabels(),rotation=90)
    for i in ax.patches:
        ax.text(x=i.get_x(),y=i.get_height(),s=i.get_height())
